# %% [markdown]
# ## Surge Tank Analysis

# %% [markdown]
# ### Hydraulics Design Sheet
# https://docs.google.com/spreadsheets/d/1O94GR2dLwGf0avGWQpIo3vhhubSqWH_q76L1GCsQIp4/edit?usp=sharing
#
# ### Connecting sheets to python

# %%
# Connecting to Google Sheets
import gspread
from google.oauth2.service_account import Credentials

scopes = ["https://www.googleapis.com/auth/spreadsheets"]
creds = Credentials.from_service_account_file("credentials.json", scopes=scopes)
client = gspread.authorize(creds)

sheet_id = "1O94GR2dLwGf0avGWQpIo3vhhubSqWH_q76L1GCsQIp4"
workbook = client.open_by_key(sheet_id)

# %% [markdown]
# ## Types of Surge Tanks
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Theory of Surge Tank
# 1D Navier Stokes Equations of Transient Flow
# ![image.png](attachment:image.png)

# %%
from pandasgui import show
import pandas as pd

df = pd.DataFrame({'a':[1,2,3], 'b':[4,5,6]})
df_gui=show(df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# 2026-02-15 10:49:50,065 - INFO     - Opening PandasGUI
# C:\Users\Ripple\AppData\Local\Temp\ipykernel_14604\1599400768.py:5: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Ripple\AppData\Local\Temp\ipykernel_14604\1599400768.py:5: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Ripple\AppData\Local\Temp\ipykernel_14604\1599400768.py:5: FutureWarning:
#
# ...

# %%
df=df_gui.get_dataframes('df')
df
# Out:
#    a  b
# 0  5  4
# 1  2  5
# 2  3  6

# %%
df['a']
# Out:
# 0    5
# 1    2
# 2    3
# Name: a, dtype: int64
